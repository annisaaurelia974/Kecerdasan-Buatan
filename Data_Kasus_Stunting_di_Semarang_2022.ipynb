# %% [markdown]
# <a href="https://colab.research.google.com/github/annisaaurelia974/Kecerdasan-Buatan/blob/main/Data_Kasus_Stunting_di_Semarang_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-21886e26-a835-4845-8275-d6026a8bae41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21886e26-a835-4845-8275-d6026a8bae41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

# %%
df = pd.read_csv("Penyebab Stunting.csv")
df.head(10)
# Out:
#   Penyebab Anak Mengalami Stunting  Unnamed: 1
# 0                           Gejala  Banyak (%)
# 1             Makanan tak bergizi         32,4
# 2       Kurang gizi pada ibu hamil        28,2
# 3                          Genetik        16,2
# 4          Kebersihan tak terjaga          4,8
# 5            Infeksi virus/bakteri         4,1
# 6          Tingkat ekonomi rendah          2,8
# 7                    Lain-lainnya            3
# 8                      Tidak tahu          8,5
# No charts were generated by quickchart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df = pd.read_csv("Kasus Stunting Semarang Utara.csv")
df.head(12)
# Out:
#    Kasus Stunting Kecamatan Semarang Utara Bulan September 2022  \
# 0                                                 NaN
# 1                                           Kelurahan
# 2                                        Panggung Lor
# 3                               Purwosari (Smg Utara)
# 4                                           Plombokan
# 5                                            Bulu Lor
# 6                                      Panggung Kidul
# 7                                           Dadapsari
# 8                                            Kuningan
# 9                                         Bandarharjo
# 10                                         Tanjungmas
#
#          Unnamed: 1
# 0               NaN
# 1   Jumlah Stunting
# 2                 0
# 3                 4
# 4                 4
# 5                 5
# 6                 5
# 7                18
# 8                28
# 9                70
# 10               89
# ...

# %%
df = pd.read_csv("Kasus Stunting Semarang Timur.csv")
df.head(13)
# Out:
#    Kasus Stunting Kecamatan Semarang Timur Bulan September 2022  \
# 0                                                 NaN
# 1                                           Kelurahan
# 2                                        Karangtempel
# 3                                          Karangturi
# 4                                            Bugangan
# 5                                          Kebonagung
# 6                                            Rejosari
# 7                                           Rejomulyo
# 8                                          Mlatiharjo
# 9                                            Sarirejo
# 10                                          Mlatibaru
# 11                                            Kemijen
#
#          Unnamed: 1
# 0               NaN
# 1   Jumlah Stunting
# 2                 1
# 3                 2
# 4                 2
# 5                 3
# 6                 7
# 7                 9
# 8                10
# 9                13
# ...

# %%
df = pd.read_csv("Kasus Stunting Semarang Tengah.csv")
df.head(18)
# Out:
#    Kasus Stunting Kecamatan Semarang Tengah Bulan September 2022  \
# 0                                                 NaN
# 1                                           Kelurahan
# 2                                            Pekunden
# 3                                              Miroto
# 4                                          Brumbungan
# 5                                             Jagalan
# 6                                        Karang Kidul
# 7                                         Bangunharjo
# 8                                              Kauman
# 9                                             Gabahan
# 10                                         Pandansari
# 11                                           Kranggan
# 12                                    Pindrikan Kidul
# 13                                       Purwodinatan
# 14                                      Pindrikan Lor
# 15                                        Kembangsari
# ...

# %%
df = pd.read_csv("Kasus Stunting Semarang Selatan.csv")
df.head(13)
# Out:
#    Kasus Stunting Kecamatan Semarang Selatan Bulan September 2022  \
# 0                                                 NaN
# 1                                           Kelurahan
# 2                                        Lamper Kidul
# 3                                            Pleburan
# 4                                           Mugassari
# 5                                            Barusari
# 6                                          Lamper Lor
# 7                                          Bulustalan
# 8                                             Wonodri
# 9                                          Peterongan
# 10                                          Randusari
# 11                                      Lamper Tengah
#
#          Unnamed: 1
# 0               NaN
# 1   Jumlah Stunting
# 2                 4
# 3                 5
# 4                 6
# 5                 7
# 6                 7
# 7                 8
# 8                11
# 9                11
# ...

# %%
df = pd.read_csv("Kasus Stunting Semarang Barat.csv")
df.head(19)
# Out:
#    Kasus Stunting Kecamatan Semarang Barat Bulan September 2022  \
# 0                                                 NaN
# 1                                           Kelurahan
# 2                                             Krapyak
# 3                                        Salamanmloyo
# 4                                         Tawang Sari
# 5                                              Cabean
# 6                                   Kalibanteng Kidul
# 7                                         Tambakharjo
# 8                                           Karangayu
# 9                                      Bojong Salaman
# 10                                  Kalibanteng Kulon
# 11                                         Tawang Mas
# 12                                  Ngemplak Simongan
# 13                                         Gisikdrono
# 14                                           Krobokan
# 15                                           Bongsari
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Kasus Stunting Kecamatan Semarang Barat Bulan September 2022  17 non-null     object
#  1   Unnamed: 1                                                    17 non-null     object
# dtypes: object(2)
# memory usage: 416.0+ bytes

# %%
import matplotlib.pyplot as plt

labels = ['Makanan tak bergizi', 'Kurang gizi pada ibu hamil', 'Genetik', 'Kebersihan tak terjaga', 'inveksi virus', 'Tingkat ekonomi rendah', 'Lain-lainnya', 'Tidak tahu']
quantity = [32.4, 28.2, 16.2, 4.8, 4.1, 2.8, 3, 8.5]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

plt.title('Kasus Stunting di Kota Semarang')
plt.pie(quantity, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')
plt.show()

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of     Kasus Stunting Kecamatan Semarang Barat Bulan September 2022  Unnamed: 1
# 0                                                True                   True
# 1                                               False                  False
# 2                                               False                  False
# 3                                               False                  False
# 4                                               False                  False
# 5                                               False                  False
# 6                                               False                  False
# 7                                               False                  False
# 8                                               False                  False
# 9                                               False                  False
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Kasus Stunting Kecamatan Semarang Barat Bulan September 2022, Unnamed: 1]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_27.sort_values('index', ascending=True)
# ...

# %%
# !pip install pandas matplotlib

import pandas as pd
import matplotlib.pyplot as plt

def upload_csv():
    from google.colab import files

    uploaded = files.upload()

    file_name = list(uploaded.keys())[0]

    return file_name

uploaded_file = upload_csv()
# Out:
# ...
#      <input type="file" id="files-5cf37950-7969-4f6a-b493-c5ca648517d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5cf37950-7969-4f6a-b493-c5ca648517d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from IPython.display import display, HTML

def all_data(file_path, num_rows=None):
    df = pd.read_csv(file_path)

    if num_rows is None:
        num_rows = len(df)
    print(f"Kasus Stunting Kecamatan Semarang Barat Bulan September 2022	")

    display(HTML(df.head(num_rows).to_html(index=False)))

all_data(uploaded_file)
# Out:
# Kasus Stunting Kecamatan Semarang Barat Bulan September 2022
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Kasus Stunting Kecamatan Semarang Barat Bulan September 2022</th>
#       <th>Unnamed: 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>Kelurahan</td>
#       <td>Jumlah Stunting</td>
#     </tr>
#     <tr>
#       <td>Krapyak</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Salamanmloyo</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Tawang Sari</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Cabean</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Kalibanteng Kidul</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Tambakharjo</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Karangayu</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Bojong Salaman</td>
#       <td>7</td>
# ...

# %%
df.describe()
# Out:
#        Kasus Stunting Kecamatan Semarang Barat Bulan September 2022 Unnamed: 1
# count                                                  17                   17
# unique                                                 17                   10
# top                                             Kelurahan                    7
# freq                                                    1                    3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3a71e4c-8296-4bd5-aa5b-f2971746b401" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3a71e4c-8296-4bd5-aa5b-f2971746b401">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Penggunaan Matplotlib untuk membuat scatter plot.

import matplotlib.pyplot as plt

# Data
Kelurahan = ["Lamperkidul", "Pleburan", "Mugassari", "Barusari", "Lamper lor", "Bulustalan", "Wonodri", "Peterongan", "Randusari", "Lamper tengah", "Karangtempel", "Karangturi",
             "Bugangan", "Kebonagung", "Rejosari", "Rejomulyo", "Mlatiharjo", "Sarirejo", "Mlatibaru", "Kemijen", "Krapyak", "Salamanmloyo", "Tawang sari", "Cabean", "Kalibanteng kidul",
             "Tambakharjo", "Karangayu", "Bojong salaman", "Kalibanteng kulon", "Tawang mas", "Ngemplak simongan", "Gisikdrono", "Krobokan", "Bongsari", "Kembangarum", "Manyaran", "Pekunden",
             "Miroto", "Brumbungan", "Jagalan", "Karang kidul", "Bangunharjo", "Kauman", "Gabahan", "Pandansari", "Karangan", "Pindrikan kidul", "Purwodinatan", "Pindrikan lor", "Kembangsari",
             "Sekayu", "Panggung lor", "Purwosari (smg utara)", "Plombokan", "Bulu lor", "Panggung kidul", "Dadapsari", "Kuningan", "Bandarharjo", "Tanjungmas"]
Jumlah_Kasus = [4, 5, 6, 7, 7, 8, 11, 11, 12, 22, 1, 2, 2, 3, 7, 9, 10, 13, 22, 49, 0, 1, 1, 2, 2, 3, 7, 7, 7, 12, 12, 13, 15, 15, 15, 18, 1, 2, 2, 3, 3, 4, 4, 5, 6, 8, 8, 9, 12, 12, 13,
                0, 4, 4, 5, 5, 18, 28, 70, 89]

# membuat scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(Kelurahan, Jumlah_Kasus, label='2022')

#Menambahkan tabel sumbu dan judul
plt.xlabel('Kelurahan')
plt.ylabel('Prevalensi Stunting')
plt.title('Prevalensi Stunting di Berbagai Kelurahan')

# Menambah legenda
plt.legend()

# Mengatur agar label sumbu x tidak tumpang tindih
plt.xticks(rotation=90)

#menampilkan plot
plt.show()

# %%
# Penggunaan Matplotlib untuk membuat bar plot

import matplotlib.pyplot as plt

# Data
Kelurahan = ["Lamperkidul", "Pleburan", "Mugassari", "Barusari", "Lamper lor", "Bulustalan", "Wonodri", "Peterongan", "Randusari", "Lamper tengah",
             "Karangtempel", "Karangturi", "Bugangan", "Kebonagung", "Rejosari", "Rejomulyo", "Mlatiharjo", "Sarirejo", "Mlatibaru", "Kemijen",
             "Krapyak", "Salamanmloyo", "Tawang sari", "Cabean", "Kalibanteng kidul", "Tambakharjo", "Karangayu", "Bojong salaman",
             "Kalibanteng kulon", "Tawang mas", "Ngemplak simongan", "Gisikdrono", "Krobokan", "Bongsari", "Kembangarum", "Manyaran", "Pekunden",
             "Miroto", "Brumbungan", "Jagalan", "Karang kidul", "Bangunharjo", "Kauman", "Gabahan", "Pandansari", "Karangan", "Pindrikan kidul",
             "Purwodinatan", "Pindrikan lor", "Kembangsari", "Sekayu", "Panggung lor", "Purwosari (smg utara)", "Plombokan",
             "Bulu lor", "Panggung kidul", "Dadapsari", "Kuningan", "Bandarharjo", "Tanjungmas"]
Jumlah_Kasus = [4, 5, 6, 7, 7, 8, 11, 11, 12, 22, 1, 2, 2, 3, 7, 9, 10, 13, 22, 49, 0, 1, 1, 2, 2, 3, 7, 7, 7, 12, 12,
                13, 15, 15, 15, 18, 1, 2, 2, 3, 3, 4, 4, 5, 6, 8, 8, 9, 12, 12, 13,
                0, 4, 4, 5, 5, 18, 28, 70, 89]

# Membuat bar plot
plt.figure(figsize=(15, 6))
plt.bar(Kelurahan, Jumlah_Kasus, color='skyblue')

# Menambahkan tabel sumbu dan judul
plt.xlabel('Kelurahan')
plt.ylabel('Jumlah Kasus Stunting')
plt.title('Jumlah Kasus Stunting di Berbagai Kelurahan')

# Mengatur agar label sumbu x tidak tumpang tindih
plt.xticks(rotation=90)

# Menampilkan plot
plt.show()
